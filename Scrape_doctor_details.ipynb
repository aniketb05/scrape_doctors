# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
data = pd.DataFrame(columns = ['doc_name', 'qualifications', 'specialities', 'verification_label', 'practo_score', 'practo_votes', 'description', 'clinics'])

# %%
def clean_text(tag_text):
    return re.sub(' ,', ',', re.sub('\s+', ' ', tag_text))

# %%
def get_doctor_data(doc_url):
    r = requests.get(doc_url)
    data = r.content
    soup = BeautifulSoup(data, 'lxml')
    
    # Retrieving name of the doctor
    name = soup.find('h1', class_='doctor-name').text.encode('utf-8')
    
    # Retrieving doctor's qualifications
    qual = soup.find('p', class_='doctor-qualifications').text.encode('utf-8').strip()
    qualifications = clean_text(qual)
    
    # Retrieving doctor's specialities
    spec = soup.find('h2', class_='doctor-specialties').text.encode('utf-8').strip()
    specialities =  clean_text(spec)
    
    # Retrieving doctor's verification status
    try:
        verification_label = soup.find('span', class_='verification-label').text.encode('utf-8').strip()
    except:
        verification_label = 'Not Verified'
        
    # Retrieving doctor's practo trust score and number of votes
    try:
        patient_experience_score = soup.find('div', class_='patient_experience_score').text.encode('utf-8').strip()
        votes_string = soup.find('span', class_='doctor-votes').text.encode('utf-8').strip()
        votes = int(re.sub(r'\D', "",votes_string))
        score = int(re.sub(r'\D', "",patient_experience_score) .replace(str(votes),''))
    except:
        score = 'Not Scored'
        votes = 0
    
    # Retrieving doctor's practo description
    desc = soup.find('meta', attrs = {'itemprop':'description'})
    description = desc['content'].encode('utf-8')
    
    # Retrieving clinics' details
    clinics_data = soup.find_all('div', class_= 'clinic-block', recursive = True)
    clinics = {}
    for i, clinic in enumerate(clinics_data):
        clinic_data = {}
        
        clinic_data['clinic_name'] = clinic.find('div', class_ = 'clinic-address').h2.text.encode('utf-8')
        clinic_data['locality'], clinic_data['city'] = clinic.find('div', class_ = 'clinic-locality').h2.text.encode('utf-8'), clinic.find('div', class_ = 'clinic-locality').span.text.encode('utf-8')
        clinic_data['clinic_address'] = clinic.find('p', class_ = 'clinic-street-address').text.encode('utf-8').strip()
        clinic_data['clinic_url'] = clinic.find('div', class_ = 'clinic-address').h2.a['href']
        
        clinic_data['clinic_geo_coordinates'] = {}
        try:
            clinic_data['clinic_geo_coordinates']['latitude'] = float(clinic.find('p', class_ = 'map-link-container').find_all('meta')[0]['content'])
            clinic_data['clinic_geo_coordinates']['longitude'] = float(clinic.find('p', class_ = 'map-link-container').find_all('meta')[1]['content'])
        except:
            clinic_data['clinic_geo_coordinates']['latitude'] = 'NA'
            clinic_data['clinic_geo_coordinates']['longitude'] = 'NA'
        
        clinic_timings_raw = clinic.find('div', class_='clinic-timings').text.encode('utf-8')
        clinic_data[ 'clinic_timings'] = clean_text(clinic_timings_raw)
        if clinic_data[ 'clinic_timings'] ==' ':
            clinic_data[ 'clinic_timings'] = 'Not Mentioned'
        clinics[str(i)] = clinic_data
    return [name, qualifications, specialities, verification_label, score, votes, description, clinics]

# %%
list_filename = 'ophthalmologist.txt'
with open(list_filename) as f: 
    for url in f:
        url = url.strip()
        data.loc[-1] = get_doctor_data(url)  # adding a row
        data.index = data.index + 1  # shifting index
        data = data.sort_index()

# %%
data
# Out:
#                              doc_name  \
# 0                   Dr. Nirav Agarwat
# 1                    Dr. Mukul Sharma
# 2                    Dr. Mukul Sharma
# 3                      Dr Nirav Davda
# 4           Dr. Somchand Kannji Salva
# 5                 Dr. Vimal Fudnawala
# 6    Dr. Bhagat Vivian Jagdishchandra
# 7                  Dr Chinchalkar B C
# 8           Dr. Somchand Kannji Salva
# 9                    Dr. Priya Rajput
# 10               Dr. Sangita B. Manek
# 11                Dr. Krishna Malekar
# 12               Dr. Mehul P. Sanghav
# 13                     Dr. Somen Seth
# 14                      Dr. Noorjahan
# 15         Dr. Nivvedita Patil Kartik
# 16                       Dr. R Maniar
# 17                  Dr. Bhabi Chawala
# 18               Dr. Jayashree Divate
# 19                       Dr. H Kodial
# 20                 Dr. Vipul V. Vakil
# 21                   Dr. Aditya Kapil
# 22                   Dr. Sunil Vasani
# 23                  Dr. Bhavesh Pokar
# 24                   Dr. Brijesh Shah
# 25                  Dr. Namrata Joshi
# 26                  Dr. Zalak R Galia
# 27                  Dr. Ketki Purecha
# 28                  Dr. Sudhir Sudrik
# 29                Dr. Ninu Shah Almel
# ..                                ...
# 490                 Dr. Sunil S. Jain
# 491                 Dr. Chetan I Shah
# 492                  Dr. Jigar Bathia
# 493                  Dr. A. K. Tandon
# 494               Dr. Nitin Deshpande
# 495                  Dr. Nikhil Nasta
# 496                 Dr. Bhavesh Gohil
# 497               Dr. Bhavisha Bansal
# 498               Dr. Smita Mukherjee
# 499           Dr. Vinit Mahendra Shah
# 500                   Dr. Jenin Patel
# 501                   Dr. Jatin Ashar
# 502                 Dr. Vrinda Raikar
# 503              Dr. Suvarna Koppikar
# 504               Dr. Nishikant Borse
# 505               Dr. Rajul S. Parikh
# 506            Dr. Neepa Thacker Dave
# 507                 Dr. Vinod C Mehta
# 508                 Dr. Vinay Agrawal
# 509                   Dr. S.Natarajan
# 510                 Dr. Keiki R Mehta
# 511           Dr. Siddharth Kesarwani
# 512                 Dr. Kamlesh Gupta
# 513                  Dr. Shradha Goel
# 514                 Dr. Niteen Dedhia
# 515                   Dr. Nita A Shah
# 516             Dr. Nikhil S. Gokhale
# 517                Dr. Chaitanya Vemu
# 518                Dr. Abhijeet Desai
# 519               Dr. Darshana Gadgil
#
#                                         qualifications  \
# 0                             MBBS, MS - Ophthalmology
# 1                             MBBS, MS - Ophthalmology
# 2                             MBBS, MS - Ophthalmology
# 3                                   MS - Ophthalmology
# 4                             MBBS, MS - Ophthalmology
# 5                             MBBS, MS - Ophthalmology
# 6                             MBBS, MS - Ophthalmology
# 7                             MBBS, MS - Ophthalmology
# 8                             MBBS, MS - Ophthalmology
# 9                             MBBS, MS - Ophthalmology
# 10                                          MBBS, DOMS
# 11                            MBBS, MS - Ophthalmology
# 12                      MBBS, MS - Ophthalmology, DOMS
# 13                            MBBS, MS - Ophthalmology
# 14                            MBBS, MS - Ophthalmology
# 15                                          MBBS, DOMS
# 16                            MBBS, MS - Ophthalmology
# 17                            MBBS, MS - Ophthalmology
# 18                                          MBBS, DOMS
# 19                            MBBS, MS - Ophthalmology
# 20                            MBBS, MS - Ophthalmology
# 21                      MBBS, MS - Ophthalmology, DOMS
# 22                            MBBS, MS - Ophthalmology
# 23       MS - Ophthalmology, FCPS - Mid. & Gynae, DOMS
# 24                      MBBS, MS - Ophthalmology, DOMS
# 25                            MBBS, MS - Ophthalmology
# 26                           MBBS, DNB - Ophthalmology
# 27                    MBBS, DNB - Ophthalmology, FICOI
# 28                            MBBS, MS - Ophthalmology
# 29                      MBBS, MS - Ophthalmology, DOMS
# ..                                                 ...
# 490  F.L.V.P.E.I, DNB - Ophthalmology, MNAMS Ophtha...
# 491                           MS - Ophthalmology, MBBS
# 492  MS - Ophthalmology, DOMS, FCPS- Ophthalmology,...
# 493                           MBBS, MS - Ophthalmology
# 494  DNB - Ophthalmology, Fellowship in Glaucoma, F...
# 495      MBBS, DNB - Ophthalmology, MS - Ophthalmology
# 496  MBBS, MS - Ophthalmology, DNB - Ophthalmology,...
# 497  MBBS, MS - Ophthalmology, F.C.P.S, DOMS, DNB -...
# 498  MBBS, MS - Ophthalmology, DOMS, DNB - Ophthalm...
# 499                           MBBS, MD - Ophthalmology
# 500      MBBS, MS - Ophthalmology, DNB - Ophthalmology
# 501  MBBS, MD - Ophthalmology, DNB - Ophthalmology,...
# 502  MBBS, MS - Ophthalmology, DOMS, Cornea Fellows...
# 503                           MS - Ophthalmology, MBBS
# 504                  MBBS, F.M.R.F, MS - Ophthalmology
# 505  MBBS, Post Graduate Diploma in Ophthalmology, ...
# 506  MS - Ophthalmology, DNB - Ophthalmology, FRCS ...
# 507                                 MS - Ophthalmology
# 508  MS - Ophthalmology, DNB - Ophthalmology, Fello...
# 509                                   MBBS, DOMS, FRVS
# 510       MBBS, Post Graduate Diploma in Ophthalmology
# 511  MBBS, MS - Ophthalmology, DNB - Ophthalmology,...
# 512                MBBS, MD - Ophthalmology, FICO (UK)
# 513                           MS - Ophthalmology, MBBS
# 514                     MS - Ophthalmology, DOMS, MBBS
# 515                           MBBS, MS - Ophthalmology
# 516  MBBS, MD - Ophthalmology, DNB - Ophthalmology,...
# 517  MBBS, MS - Ophthalmology, DNB - Ophthalmology,...
# 518  MBBS, MS - Ophthalmology, DNB - Ophthalmology,...
# 519  MBBS, DOMS, FCPS- Ophthalmology, Post Graduate...
#
#                                           specialities  \
# 0                         Ophthalmologist/ Eye Surgeon
# 1                         Ophthalmologist/ Eye Surgeon
# 2                         Ophthalmologist/ Eye Surgeon
# 3                         Ophthalmologist/ Eye Surgeon
# 4                         Ophthalmologist/ Eye Surgeon
# 5                         Ophthalmologist/ Eye Surgeon
# 6                         Ophthalmologist/ Eye Surgeon
# 7                         Ophthalmologist/ Eye Surgeon
# 8                         Ophthalmologist/ Eye Surgeon
# 9                         Ophthalmologist/ Eye Surgeon
# 10                        Ophthalmologist/ Eye Surgeon
# 11                        Ophthalmologist/ Eye Surgeon
# 12                        Ophthalmologist/ Eye Surgeon
# 13                        Ophthalmologist/ Eye Surgeon
# 14                        Ophthalmologist/ Eye Surgeon
# 15                        Ophthalmologist/ Eye Surgeon
# 16                        Ophthalmologist/ Eye Surgeon
# 17                        Ophthalmologist/ Eye Surgeon
# 18                        Ophthalmologist/ Eye Surgeon
# 19                        Ophthalmologist/ Eye Surgeon
# 20                        Ophthalmologist/ Eye Surgeon
# 21                        Ophthalmologist/ Eye Surgeon
# 22                        Ophthalmologist/ Eye Surgeon
# 23                        Ophthalmologist/ Eye Surgeon
# 24                        Ophthalmologist/ Eye Surgeon
# 25                        Ophthalmologist/ Eye Surgeon
# 26                        Ophthalmologist/ Eye Surgeon
# 27                        Ophthalmologist/ Eye Surgeon
# 28                        Ophthalmologist/ Eye Surgeon
# 29                        Ophthalmologist/ Eye Surgeon
# ..                                                 ...
# 490  Ophthalmologist/ Eye Surgeon, 20 Years Experience
# 491  Ophthalmologist/ Eye Surgeon, 21 Years Experience
# 492  Ophthalmologist/ Eye Surgeon, 18 Years Experience
# 493  Ophthalmologist/ Eye Surgeon, 32 Years Experience
# 494  Ophthalmologist/ Eye Surgeon, 17 Years Experience
# 495  Ophthalmologist/ Eye Surgeon, 13 Years Experience
# 496  Ophthalmologist/ Eye Surgeon, 13 Years Experience
# 497   Ophthalmologist/ Eye Surgeon, 7 Years Experience
# 498  Ophthalmologist/ Eye Surgeon, 29 Years Experience
# 499   Ophthalmologist/ Eye Surgeon, 7 Years Experience
# 500  Ophthalmologist/ Eye Surgeon, 10 Years Experience
# 501   Ophthalmologist/ Eye Surgeon, 8 Years Experience
# 502  Ophthalmologist/ Eye Surgeon, 19 Years Experience
# 503  Ophthalmologist/ Eye Surgeon, 26 Years Experience
# 504  Ophthalmologist/ Eye Surgeon, 22 Years Experience
# 505  Ophthalmologist/ Eye Surgeon, 22 Years Experience
# 506  Ophthalmologist/ Eye Surgeon, 24 Years Experience
# 507  Ophthalmologist/ Eye Surgeon, 35 Years Experience
# 508  Ophthalmologist/ Eye Surgeon, 22 Years Experience
# 509  Ophthalmologist/ Eye Surgeon, 32 Years Experience
# 510  Ophthalmologist/ Eye Surgeon, 36 Years Experience
# 511  Ophthalmologist/ Eye Surgeon, 11 Years Experience
# 512  Ophthalmologist/ Eye Surgeon, 14 Years Experience
# 513  Ophthalmologist/ Eye Surgeon, 12 Years Experience
# 514  Ophthalmologist/ Eye Surgeon, 32 Years Experience
# 515  Ophthalmologist/ Eye Surgeon, 32 Years Experience
# 516  Ophthalmologist/ Eye Surgeon, 30 Years Experience
# 517  Ophthalmologist/ Eye Surgeon, 11 Years Experience
# 518  Ophthalmologist/ Eye Surgeon, 18 Years Experience
# 519  Ophthalmologist/ Eye Surgeon, 14 Years Experience
#
#                 verification_label practo_score  practo_votes  \
# 0                     Not Verified   Not Scored           0.0
# 1                     Not Verified   Not Scored           0.0
# 2                     Not Verified   Not Scored           0.0
# 3                     Not Verified   Not Scored           0.0
# 4                     Not Verified   Not Scored           0.0
# 5                     Not Verified   Not Scored           0.0
# 6                     Not Verified   Not Scored           0.0
# 7                     Not Verified   Not Scored           0.0
# 8                     Not Verified   Not Scored           0.0
# 9                     Not Verified   Not Scored           0.0
# 10                    Not Verified   Not Scored           0.0
# 11                    Not Verified   Not Scored           0.0
# 12                    Not Verified   Not Scored           0.0
# 13                    Not Verified   Not Scored           0.0
# 14                    Not Verified   Not Scored           0.0
# 15                    Not Verified   Not Scored           0.0
# 16                    Not Verified   Not Scored           0.0
# 17                    Not Verified   Not Scored           0.0
# 18                    Not Verified   Not Scored           0.0
# 19                    Not Verified   Not Scored           0.0
# 20                    Not Verified   Not Scored           0.0
# 21                    Not Verified   Not Scored           0.0
# 22                    Not Verified   Not Scored           0.0
# 23                    Not Verified   Not Scored           0.0
# 24                    Not Verified   Not Scored           0.0
# 25                    Not Verified   Not Scored           0.0
# 26                    Not Verified   Not Scored           0.0
# 27                    Not Verified   Not Scored           0.0
# 28                    Not Verified   Not Scored           0.0
# 29                    Not Verified   Not Scored           0.0
# ..                             ...          ...           ...
# 490  Medical Registration Verified            0          10.0
# 491  Medical Registration Verified           80          10.0
# 492  Medical Registration Verified           98        1437.0
# 493  Medical Registration Verified           97         447.0
# 494  Medical Registration Verified           99         394.0
# 495  Medical Registration Verified           99         600.0
# 496  Medical Registration Verified           99         316.0
# 497  Medical Registration Verified           98         510.0
# 498  Medical Registration Verified           99         240.0
# 499  Medical Registration Verified           98        1007.0
# 500  Medical Registration Verified           96         317.0
# 501  Medical Registration Verified           96         623.0
# 502  Medical Registration Verified          100         252.0
# 503  Medical Registration Verified   Not Scored           0.0
# 504  Medical Registration Verified           96          93.0
# 505  Medical Registration Verified           98        1014.0
# 506  Medical Registration Verified           96          26.0
# 507  Medical Registration Verified           99         515.0
# 508  Medical Registration Verified           97          31.0
# 509  Medical Registration Verified           80          10.0
# 510  Medical Registration Verified   Not Scored           0.0
# 511  Medical Registration Verified           99         622.0
# 512  Medical Registration Verified           98        1273.0
# 513  Medical Registration Verified           99         567.0
# 514  Medical Registration Verified           97         169.0
# 515  Medical Registration Verified           91          89.0
# 516  Medical Registration Verified           95          19.0
# 517  Medical Registration Verified           99          97.0
# 518  Medical Registration Verified           90          31.0
# 519  Medical Registration Verified           98         294.0
#
#                                            description  \
# 0    Dr. Nirav Agarwat is an Ophthalmologist/ Eye S...
# 1    Dr. Mukul Sharma is an Ophthalmologist/ Eye Su...
# 2    Dr. Mukul Sharma is an Ophthalmologist/ Eye Su...
# 3    Dr Nirav Davda is an Ophthalmologist/ Eye Surg...
# 4    Dr. Somchand Kannji Salva is an Ophthalmologis...
# 5    Dr. Vimal Fudnawala is an Ophthalmologist/ Eye...
# 6    Dr. Bhagat Vivian Jagdishchandra is an Ophthal...
# 7    Dr Chinchalkar B C is an Ophthalmologist/ Eye ...
# 8    Dr. Somchand Kannji Salva is an Ophthalmologis...
# 9    Dr. Priya Rajput is an Ophthalmologist/ Eye Su...
# 10   Dr. Sangita B. Manek is an Ophthalmologist/ Ey...
# 11   Dr. Krishna Malekar is an Ophthalmologist/ Eye...
# 12   Dr. Mehul P. Sanghav is an Ophthalmologist/ Ey...
# 13   Dr. Somen Seth is an Ophthalmologist/ Eye Surg...
# 14   Dr. Noorjahan is an Ophthalmologist/ Eye Surge...
# 15   Dr. Nivvedita Patil Kartik is an Ophthalmologi...
# 16   Dr. R Maniar is an Ophthalmologist/ Eye Surgeo...
# 17   Dr. Bhabi Chawala is an Ophthalmologist/ Eye S...
# 18   Dr. Jayashree Divate is an Ophthalmologist/ Ey...
# 19   Dr. H Kodial is an Ophthalmologist/ Eye Surgeo...
# 20   Dr. Vipul V. Vakil is an Ophthalmologist/ Eye ...
# 21   Dr. Aditya Kapil is an Ophthalmologist/ Eye Su...
# 22   Dr. Sunil Vasani is an Ophthalmologist/ Eye Su...
# 23   Dr. Bhavesh Pokar is an Ophthalmologist/ Eye S...
# 24   Dr. Brijesh Shah is an Ophthalmologist/ Eye Su...
# 25   Dr. Namrata Joshi is an Ophthalmologist/ Eye S...
# 26   Dr. Zalak R Galia is an Ophthalmologist/ Eye S...
# 27   Dr. Ketki Purecha is an Ophthalmologist/ Eye S...
# 28   Dr. Sudhir Sudrik is an Ophthalmologist/ Eye S...
# 29   Dr. Ninu Shah Almel is an Ophthalmologist/ Eye...
# ..                                                 ...
# 490  Glaucoma And Cataract Specialist.<br/><br/>Dr....
# 491  Dr. Chetan I Shah is an Ophthalmologist/ Eye S...
# 492  Dr. Jigar Bathia finished his M.B.B.S. from Gr...
# 493  Dr. A.K Tandon has done his MBBS and M.S (Opht...
# 494  Dr. Nitin Deshpande is known for excellent rap...
# 495  Being a Gold Medallist in MBBS from DY Patil C...
# 496  Dr. Bhavesh Gohil is an Ophthalmologist/ Eye S...
# 497  Dr. Bhavisha secured 112th rank in MH-CET, she...
# 498  Dr. Smita Mukherjee, has more than 25 years of...
# 499  Dr. Vinit M Shah is the director and the princ...
# 500  Dr. Jenin Patel has earned a name and fame by ...
# 501  Dr. Ashar has done his post graduation from th...
# 502  Dr Vrinda Raikar is an Ophthalmologist/ Eye su...
# 503  Dr. Suvarna Koppikar is an Ophthalmologist/ Ey...
# 504  Dr Nishikant Borse is a consulting Retinologis...
# 505  Dr. Rajul s parikh has done his masters in oph...
# 506  Dr. Neepa Thacker Dave is an Ophthalmologist/ ...
# 507  I am Chief and Founder Ophthalmologist at Meht...
# 508  Dr. Vinay Agrawal is an Ophthalmologist/ Eye S...
# 509  Professor Dr. Sundaram Natarajan is the CMD of...
# 510  Dr. Keiki R Mehta is a Chief Surgical and Medi...
# 511  Dr. Siddharth Kesarwani is a well known figure...
# 512  Dr. Kamlesh Gupta is an Ophthalmologist/ Eye S...
# 513  Dr. Shradha Goel after finishing her M.B.B.S. ...
# 514  Firm belief, dedicated goals and sheer hard wo...
# 515  It is rare that we come across the likes of Dr...
# 516  Dr. Nikhil S. Gokhale is an Ophthalmologist/ E...
# 517  Dr. Chaitanya Vemu  has earned a name and fame...
# 518  Dr. Abhijeet Desai is an Ophthalmologist/ Eye ...
# 519  By Appointment Only..... You can book an insta...
#
#                                                clinics
# 0    {u'0': {u'city': u'Mumbai', u'locality': u'Mir...
# 1    {u'1': {u'city': u'Mumbai', u'locality': u'Byc...
# 2    {u'1': {u'city': u'Mumbai', u'locality': u'Byc...
# 3    {u'0': {u'city': u'Mumbai', u'locality': u'Mal...
# 4    {u'1': {u'city': u'Mumbai', u'locality': u'Dad...
# 5    {u'0': {u'city': u'Mumbai', u'locality': u'Wad...
# 6    {u'0': {u'city': u'Mumbai', u'locality': u'Bor...
# 7    {u'0': {u'city': u'Mumbai', u'locality': u'Mal...
# 8    {u'1': {u'city': u'Mumbai', u'locality': u'Dad...
# 9    {u'1': {u'city': u'Mumbai', u'locality': u'Mal...
# 10   {u'0': {u'city': u'Mumbai', u'locality': u'Mul...
# 11   {u'0': {u'city': u'Mumbai', u'locality': u'Mul...
# 12   {u'0': {u'city': u'Mumbai', u'locality': u'Mul...
# 13   {u'0': {u'city': u'Mumbai', u'locality': u'Gor...
# 14   {u'0': {u'city': u'Mumbai', u'locality': u'Bha...
# 15   {u'0': {u'city': u'Mumbai', u'locality': u'Ope...
# 16   {u'0': {u'city': u'Mumbai', u'locality': u'Ope...
# 17   {u'0': {u'city': u'Mumbai', u'locality': u'Chu...
# 18   {u'0': {u'city': u'Mumbai', u'locality': u'Bor...
# 19   {u'0': {u'city': u'Mumbai', u'locality': u'Ope...
# 20   {u'0': {u'city': u'Mumbai', u'locality': u'Kan...
# 21   {u'0': {u'city': u'Mumbai', u'locality': u'Mul...
# 22   {u'0': {u'city': u'Mumbai', u'locality': u'Tar...
# 23   {u'0': {u'city': u'Mumbai', u'locality': u'Mul...
# 24   {u'0': {u'city': u'Mumbai', u'locality': u'Vil...
# 25   {u'0': {u'city': u'Mumbai', u'locality': u'Ban...
# 26   {u'0': {u'city': u'Mumbai', u'locality': u'Nal...
# 27   {u'0': {u'city': u'Mumbai', u'locality': u'Mir...
# 28   {u'0': {u'city': u'Mumbai', u'locality': u'Mir...
# 29   {u'0': {u'city': u'Mumbai', u'locality': u'Mul...
# ..                                                 ...
# 490  {u'1': {u'city': u'Mumbai', u'locality': u'Gha...
# 491  {u'1': {u'city': u'Mumbai', u'locality': u'Mir...
# 492  {u'0': {u'city': u'Mumbai', u'locality': u'Bor...
# 493  {u'1': {u'city': u'Mumbai', u'locality': u'Vil...
# 494  {u'1': {u'city': u'Mumbai', u'locality': u'Mul...
# 495  {u'1': {u'city': u'Mumbai', u'locality': u'Kha...
# 496  {u'0': {u'city': u'Mumbai', u'locality': u'Wad...
# 497  {u'1': {u'city': u'Mumbai', u'locality': u'Kan...
# 498  {u'1': {u'city': u'Navi Mumbai', u'locality': ...
# 499  {u'0': {u'city': u'Mumbai', u'locality': u'Bor...
# 500  {u'0': {u'city': u'Mumbai', u'locality': u'Mal...
# 501  {u'1': {u'city': u'Mumbai', u'locality': u'Ban...
# 502  {u'0': {u'city': u'Mumbai', u'locality': u'Che...
# 503  {u'0': {u'city': u'Mumbai', u'locality': u'And...
# 504  {u'1': {u'city': u'Mumbai', u'locality': u'Mat...
# 505  {u'1': {u'city': u'Mumbai', u'locality': u'And...
# 506  {u'1': {u'city': u'Mumbai', u'locality': u'Vil...
# 507  {u'0': {u'city': u'Mumbai', u'locality': u'Gha...
# 508  {u'1': {u'city': u'Mumbai', u'locality': u'Mat...
# 509  {u'0': {u'city': u'Mumbai', u'locality': u'Wad...
# 510  {u'0': {u'city': u'Mumbai', u'locality': u'Col...
# 511  {u'1': {u'city': u'Mumbai', u'locality': u'Bor...
# 512  {u'0': {u'city': u'Mumbai', u'locality': u'Mir...
# 513  {u'0': {u'city': u'Mumbai', u'locality': u'And...
# 514  {u'1': {u'city': u'Mumbai', u'locality': u'Kan...
# 515  {u'0': {u'city': u'Mumbai', u'locality': u'Che...
# 516  {u'0': {u'city': u'Mumbai', u'locality': u'Dad...
# 517  {u'1': {u'city': u'Mumbai', u'locality': u'Gha...
# 518  {u'1': {u'city': u'Mumbai', u'locality': u'Bor...
# 519  {u'1': {u'city': u'Mumbai', u'locality': u'Dad...
#
# [520 rows x 8 columns]

# %%
data.to_csv('ophthalmologist_info.csv')
